# %% [markdown]
# ## Tarea 1 (Estructura de Internet & HTTP)
#
# La tarea la hicimos en este formato, ya que, se nos acomoda mas el poder combinar entre codigo y respuestas.

# %% [markdown]
# ### 1.- Recopile el registro de todos los saltos que realiza un paquete para alcanzar el dominio imt-atlantique.fr. Luego, usando Google Maps capture una imagen incluya todos los lugares por donde pasaron los paquetes, marque los lugares y trace una línea que muestre el recorrido seguido. Incluya la imagen en su respuesta.
#
# |Salida de traceroute a imt-atlantique.fr |Nombre del Host | País y Ciudad |
# | - | - | - |
# | 1 Red interna usm (10.11.0.1) 3 ms... | UTFSM | Santiago, Chile |
# |  - | - | - |
# | 2 Red interna usm (10.6.8.2) 4 ms... | UTFSM | Santiago, Chile |
# |  - | - | - |
# | 3 Red interna usm (10.6.3.2) 5 ms... | UTFSM | Santiago, Chile |
# |  - | - | - |
# | 4 Red interna usm (192.168.6.7) 3 ms... | UTFSM | Santiago, Chile |
# |  - | - | - |
# | 5 Red interna usm (10.30.0.18) 2 ms... | UTFSM | Santiago, Chile |
# |  - | - | - |
# | 6 Red interna usm (10.30.0.1) 2 ms... | UTFSM | Santiago, Chile |
# |  - | - | - |
# | 7 Red interna usm (200.1.21.161) 4 ms... | UTFSM | Santiago, Chile |
# |  - | - | - |
# | 8 Red interna usm (192.168.212.161) 3 ms... | UTFSM | Santiago, Chile |
# |  - | - | - |
# | 9 cn2.et10-3-0.53.re2.gtdinternet.com (190.196.126.84) 3 ms... | GTD Internet S.A | Santiago, Chile |
# |  - | - | - |
# | 10 ci2.0-1-1.cn2.gtdinternet.com (190.196.126.240) 3 ms... | GTD Internet S.A | Santiago, Chile |
# |  - | - | - |
# | 11 Tiempo de espera agotado (x.x.x.x) ∞ ms... | Desconocido | Desconocido |
# |  - | - | - |
# | 12 Telefonica Telxius (5.53.1.97) 5 ms... | Telefonica Telxius | Móstoles, España |
# |  - | - | - |
# | 13 Tiempo de espera agotado (x.x.x.x) ∞ ms... | Desconocido | Desconocido |
# |  - | - | - |
# | 14 Telefonica Telxius (94.142.118.184) 101 ms... | Telefonica Telxius | Móstoles, España |
# |  - | - | - |
# | 15 ae5.cr6-mia1.ip4.gtt.net (208.116.240.149) 107 ms... | GTT Communications Inc. | New York, United States |
# |  - | - | - |
# | 16 et-3-3-0.cr2-par7.ip4.gtt.net (213.200.119.214) 205 ms... | GTT Communications Inc. | Cheney, United States |
# |  - | - | - |
# | 17 renater-gw-ix1.gtt.net (77.67.123.206) 222 ms... | GTT Communicatios Inc. | Versailles, France |
# |  - | - | - |
# | 18 te0-3-0-0-ren-nr-rennes-rtr-091.noc.renater.fr (193.55.204.15) 240 ms... | Renater | Versailles, France |
# |  - | - | - |
# | 19 telecom-brest-vl807-pc1-brest1-rtr-021.noc.renater.fr (193.51.188.9) 245 ms... | Renater | Reims, France |
# |  - | - | - |
# | 20 revproxy-imta-01.enst-bretagne.fr (192.108.117.237) 247 ms... |    Institut Mines Telecom (IMT) Atlantique - Bretagne | Brest, France |
# |  - | - | - |
#
# <br>
#
# <img src="response-1.png">

# %% [markdown]
# #### 2.- Responda las siguientes preguntas:
#
# ##### 2.1.- ¿Qué versión de HTTP corre su navegador?
#
# HTTP/1.1
#
# ##### 2.2.- ¿Qué versión de HTTP corre el servidor profesores.elo.utfsm.cl?
#
# HTTP/1.1
#
# ##### 2.3.- ¿Cual es la versión del servidor web alumnos.elo.utfsm.cl?
#
# Apache/2.4.6 (CentOS)
#
# ##### 2.4.- ¿Cual es la IP de su computador y el puerto asignado al zócalo de su navegador (equivale a puerto asignado)?
#
# IP: 192.168.1.94, PUERTO: 63214
#
# ##### 2.5.- ¿Cuales son las IPs de los computadores donde corren el servidor web profesores y el servidor web alumnos, y cuál es el puerto de cada servidor web?
#
#
# URL: profesores.elo.utfsm.cl, IP: 200.1.17.6, PUERTO: 80.
#
# URL: alumnos.elo.utfsm.cl, IP: 200.1.17.195, PUERTO: 80.
#
# ##### 2.6.- ¿Cuando fue modificado el archivo HTML httpTest.html?
#
# Last-Modified: Sat, 10 Apr 2021 02:16:24 GMT
#
# ##### 2.7.- ¿Cuántos bytes son pasados al proceso browser, es decir el navegador, en respuesta a su requerimiento GET del archivo HTML?
#
# Son pasados 476 bytes.
#
# ##### 2.8.- ¿Cuántos bytes son recibidos por la capa de red (IP) de su computador en la respuesta que incluye el archivo HTML?
#
# Son pasados 859 bytes.
#
# ##### 2.9.- Flexibilice el filtro para mostrar además los paquetes TCP donde su browser sea el origen o el destino de los paquetes. Estime el tiempo (ms) que el navegador inicia la petición HTTP y recibe una imagen como respuesta, diría que su navegador es persistente o no?
#
# el navegador es persistente debido a que mantiene una latencia que no varia , 8,209 milisegundos.
#
# ##### 2.10.- Estime el tiempo desde que presionó la tecla "intro" luego de ingresar su URL, hasta la llegada de la última imágen.
#
# la ultima imagen llega en 9.553520 ms (milisegundos).
#
# ##### 2.11.- Cuántas conexiones TCP son efecuadas para bajar toda la página; es decir, el html más cada objeto referenciado en ella? Una conexión TCP se inicia con mensajes para establecer la conexión (handshake) y termina con mensaje FIN de TCP
#
# <img src = "response.2.11.png">
#
# ##### 2.12.- ¿Cuántos servidores webs intervinieron para bajar todo el contenido de la página?
#
# 2 servidores , el primer servidor de ip 200.1.17.6 y el otro servidor de ip 200.1.17.195.

# %% [markdown]
# ### 3.- Limpie el caché de su navegador. Luego, mientras wireshark o tshark están capturando, descargue dos veces el siguiente archivo desde ELO Prueba.
#
# #### 3.1.- Diga si usted identifica la línea "IF-MODIFIED-SINCE" en la primera captura GET del archivo html. Muestre los campos del encabezado enviado por el browser.
#
# <img src="response-3.1.png">
#
# #### 3.2.- ¿Identifica la línea "IF-MODIFIED-SINCE" en la segunda captura GET del html? Muestre los campos del encabezado enviado por el navegador en este segundo caso
#
# <img src="response-3.2.png">
#
# #### 3.3.- Cuál es el código de estado HTTP y frase descriptiva retornada desde el servidor en la segunda respuesta GET del html? Incluya el encabezado enviado por el servidor. ¿Llegó desde el servidor el contenido solicitado por el browser? Explique su resultado.
#
# 302, Not Modified, concuerda totalmente con el estado actual del html, ya que no se ha actualizado desde la ultima fecha de descarga local del archivo.

# %% [markdown]
# ### 4.- Indague la petición condicional IF-MODIFIED-SINCE controlando la cabecera de sus consultas HTTP. Proponga una consulta GET ya sea de manera programática o mediante línea de comando en TSHARK hacia ELO Prueba. La consulta debe ser específica y retornar los datos relativos a IF-MODIFIED-SINCE como por ejemplo TimeStamp. Explique sus hallazgos.
#
# Con el script hecho pudimos obtener los datos del servidor los cuales contenian los valores de TimeStamp los cuales se muestran al ejecutar en el Script.
#
# <img src="response-4.png">

# %% [markdown]
# ### 5.- Autenticación HTTP: Borre el caché de su navegador y ciérrelo. Vuelva a ejecutarlo y corra wireshark ó tshark. Ingrese al siguiente enlace URL Ingrese el usuario y password dados en clases. Detenga la captura de wireshark y responda las siguientes preguntas:
#
# #### 5.1.- ¿Cuál es la respuesta del servidor en respuesta al mensaje HTTP GET inicial?
#
# <img src="response-5.1.png">
#
# #### 5.2.- ¿Qué campos son incluidos en el mensaje HTTP GET en el segundo mensaje GET enviado por su navegador? Borre el caché nuevamente y cierre el navegador. Vuelva a ejecutarlo y corra wireshark ó tshark.
#
# <img src="response-5.2.png">
